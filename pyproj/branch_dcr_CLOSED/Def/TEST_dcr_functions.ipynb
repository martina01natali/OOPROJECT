# %% [markdown]
# # Test notebook for dcr_functions.py

# %% [markdown]
# ## Updates to make
#
# - [x] Must run on full dataset (custom_n_events=1000) on OV3, OV4
# - [ ] Create class?

# %%
from dcr_functions import *

wf, meta = read_wf("..\\Data\\DCR\\HPKR00030_2cicli_OV3_wf.csv")
time_table = read_wf("..\\Data\\DCR\\HPKR00030_2cicli_OV3_time.csv")

wf_an, meta = analysis(wf_table=wf, meta=meta, timestamp_table=time_table,
                       custom_n_events=1000,
                       many_minima=500,
                       threshold=0.006, distance=50,
                       plot=False, save_plot=True,
                      )

wf_delta, meta = analysis_delta_t(wf_an, meta, crosstalk_thr=0.015)

plot_2d(wf_delta, meta, save=True)
# Out:
# Analysis of event number 1000
# Analysis completed.
# Number of clean minima found: 1080
# Fraction of waveforms with too many minima or -inf data ("bad_wf") on total: 1.1%
# Total acquisition time: 9.998e-04 s
# Estimated DCR: 1.080e+06 Hz
# Process completed in 467.06 s.
