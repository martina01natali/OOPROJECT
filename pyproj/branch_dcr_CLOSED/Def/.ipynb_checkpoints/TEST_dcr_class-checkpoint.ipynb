# %% [markdown]
# # TEST DarkCounts class

# %%
from dcr_class import *

# %%
files = {'wf'   : '..\\Data\\DCR\\HPKR00030_2cicli_OV5_wf.csv',
         'time' : '..\\Data\\DCR\\HPKR00030_2cicli_OV5_time.csv'}

new = DarkCounts(datafiles=files)
new.params['custom_n_events'] = 10
new.params['cross_thr'] = 0.015

# %%
new.params
# Out:
# {'custom_n_events': 10, 'thr': 0.006, 'cross_thr': 0.015, 'delay_thr': 6e-06}

# %%
new.meta
# Out:
# {'path_wf': '..\\Data\\DCR\\HPKR00030_2cicli_OV5_wf.csv',
#  'path_time': '..\\Data\\DCR\\HPKR00030_2cicli_OV5_time.csv',
#  'time_unit': 's',
#  'wf_datapoints': 6250,
#  'ampl_unit': 'V',
#  'wf_events': 1000}

# %%
a = new.analysis()
# Out:
# Analysis of event number 10
# Analysis completed.
# Number of clean minima found: 13
# Fraction of waveforms with too many minima or -inf data ("bad_wf") on total: 0.0%
# Total acquisition time: 9.998e-06 s
# Estimated DCR: 1.30e+06 Hz± 0e+00) Hz
# Process completed in 2.53 s.

# %%
b = new.analysis_noise()

# %%
new.plot_2d(save=False)

# %%
new.print_dcr()
# Out:
# Estimated DCR: (1.30e+06 ± 0e+00) Hz
#
# The relative error associated to the DCR is equal to the percentage of 'bad' waveforms detected in the provided dataset (0.0%). This is an arbitrary choice due to lack of multiple measurements on the same instrument.

# %%
print(new)
# Out:
# Metadata:
#
# path_wf                  :	..\Data\DCR\HPKR00030_2cicli_OV5_wf.csv
# path_time                :	..\Data\DCR\HPKR00030_2cicli_OV5_time.csv
# time_unit                :	s
# wf_datapoints            :	6250
# ampl_unit                :	V
# wf_events                :	1000
# total acquis time (s)    :	9.99839975999835e-06
# n clean minima           :	13
# % bad wf                 :	0.0
# DCR (Hz)                 :	1300208.0644955274
# Parameters:
#
# custom_n_events          :	10
# thr                      :	0.006
# cross_thr                :	0.015
# delay_thr                :	6e-06
