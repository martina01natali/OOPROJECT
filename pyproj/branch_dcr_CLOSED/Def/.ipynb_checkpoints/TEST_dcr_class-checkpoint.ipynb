# %% [markdown]
# # TEST DarkCounts class

# %%
from dcr_class import *

# %%
files = {'wf'   : '..\\Data\\DCR\\HPKR00030_2cicli_OV5_wf.csv',
         'time' : '..\\Data\\DCR\\HPKR00030_2cicli_OV5_time.csv'}

new = DarkCounts(datafiles=files)
new.params['custom_n_events'] = 1000
new.params['cross_thr'] = 0.015

# %%
new.params
# Out:
# {'custom_n_events': 1000, 'thr': 0.006, 'cross_thr': 0.015, 'delay_thr': 6e-06}

# %%
new.meta
# Out:
# {'path_wf': '..\\Data\\DCR\\HPKR00030_2cicli_OV5_wf.csv',
#  'path_time': '..\\Data\\DCR\\HPKR00030_2cicli_OV5_time.csv',
#  'time_unit': 's',
#  'wf_datapoints': 6250,
#  'ampl_unit': 'V',
#  'wf_events': 1000}

# %%
a = new.analysis()
# Out:
# Analysis of event number 1000
# Analysis completed.
# Number of clean minima found: 1167
# Fraction of waveforms with too many minima or -inf data ("bad_wf") on total: 4.5%
# Total acquisition time: 9.998e-04 s
# Estimated DCR: 1.167e+06 Hz
# Process completed in 27.68 s.

# %%
b = new.analysis_noise()

# %%
new.plot_2d(save=True)
